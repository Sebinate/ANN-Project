# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import pickle
# Out:
# c:\Users\User\Documents\Projects_Udemy\ANN_project\venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
model = tf.keras.models.load_model('artifacts/model/model.keras')
